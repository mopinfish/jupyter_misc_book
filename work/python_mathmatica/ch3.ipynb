# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 体重の折れ線グラフを描画する

## データセット
x = [1, 2, 3, 4, 5, 6, 7]
y = [64.8, 64.0, 68.8, 56.4, 60.3, 60.2, 68.9]

## グラフを描画
plt.plot(x, y)
plt.grid(color = '0.8')
plt.show()

# %%
# 一次関数 y = 3 * x - 24 を描画
# %matplotlib inline
import matplotlib.pyplot as plt

# データセット
x = list(range(1, 11)) # xの範囲（１〜１０）
y = []
for i in range(10):
    y.append(3 * i - 24) # y = 3x - 24

# グラフを描画
plt.plot(x, y)
plt.grid(color = '0.8')
plt.show()

# %%
# 一次関数 y = 3 * x - 24 を描画
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# データセット
x = np.array(range(1, 11)) # xの範囲（１〜１０）
y = 3 * x - 24

# グラフを描画
plt.plot(x, y)
plt.grid(color = '0.8')
plt.show()

# %%
# 連立方程式をとく
from sympy import Symbol, solve


# 式を定義
a = Symbol('a')
b = Symbol('b')
ex1 = a + b - 5
ex2 = 2 * a + b - 8

# 連立方程式の解を求める
solve((ex1, ex2))
# Out:
# {a: 3, b: 2}

# %%
## 直行する軸と交点

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-1, 6) # x軸の値
y = 1/2 * x - 1/2
y2 = -2 * x + 7

# グラフを描画
plt.plot(x, y)
plt.plot(x, y2)
plt.axis('equal')
plt.grid(color = '0.8')
plt.show()

# %%
## 直線の交点を求める
from sympy import Symbol, solve
# 文字の定義
x = Symbol('x')
y = Symbol('y')
ex1 = -3/2 * x + 6 - y
ex2 = 1/2 * x + 2 - y
print(solve((ex1, ex2)))

# グラフで確認
ex = np.arange(-1, 6)
y1 = -3/2 * ex + 6
y2 = 1/2 * ex + 2
plt.plot(ex, y1)
plt.plot(ex, y2)
plt.axis('equal')
plt.grid(color = '0.8')
plt.show()
# Out:
# {x: 2.00000000000000, y: 3.00000000000000}

# %%
# 垂直二等分線を求める

# 元の式
a1 = (5 - 1) / (6 - 0)
b1 = 1

# 線分の中点
cx = (6 + 0) / 2
cy = (5 + 1) / 2

# 線分に直交する式の傾き
a2 = -1 / a1
# 線分に直交する式の切片(b2 = y - a2 * x)
b2 = cy - a2 * cx

# 直線の式
x = np.arange(0, 7) # xの範囲
y1 = a1 * x + b1 # 元の直線
y2 = a2 * x + b2 # 垂直二等分線

# 描画
plt.figure(figsize = (20, 6))
plt.plot(x, y1)
plt.plot(x, y2)

plt.xlabel('X')
plt.ylabel('Y')
plt.axis('equal')
plt.grid(color = '0.8')
plt.show()

# %%
# 三角比を使った円の描画
plt.figure(figsize = (20, 6))
# 角度
th = np.arange(0, 360)
# 半径
r = 5
# 中心点
px = 3
py = 2
# 円周上の点pの座標
x = r * np.cos(np.radians(th)) + px
y = r * np.sin(np.radians(th)) + py

plt.plot(x, y)
plt.axis('equal')
plt.grid(color = '0.8')
plt.show()

# %%
## arc tangent
rad = np.arctan2(3, 4)
th = np.degrees(rad)
th
# Out:
# 36.86989764584402

# %%
# 三平方の定理

## 円の公式

## 半径
r = 200
x = np.arange(-r, r + 1)
y = np.sqrt(r ** 2 - x ** 2)


plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.grid(True)

# %%
## 円の中心
a = 200
b = 100

## 半径
r = 300

x = np.arange(a - r, a + r + 1)
y = np.sqrt(r ** 2 - (x - a) ** 2) + b # 円の上側
y2 = - y + 2 * b # 円の下側

plt.plot(x, y)
plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.grid(color = '0.8')
plt.show()
